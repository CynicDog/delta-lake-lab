// %% [markdown]
// # Scala in Action Notes
//
//
// Notes on Scala in Action

// %% [markdown]
// ### Chapter 01 - Why Scala?

// %%
val inc = (x: Int) => x + 1 
inc(10)
// Out:
// 11

// %%
List(1, 2, 3)
    .map((x: Int) => x + 1)
    .foreach(x => print(x + " "))
// Out:
// 2 3 4
